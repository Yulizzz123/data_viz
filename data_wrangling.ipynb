# %% [markdown]
# # Data Wrangling

# %% [markdown]
# This file merges 6 csv data sets to be exported as one file to Tableau.

# %% [markdown]
# ### I. Import libraries

# %%
import pandas as pd

# %% [markdown]
# ### II. Import csv files

# %% [markdown]
# Import all files

# %%
reviews_1 = pd.read_csv("raw_data/reviews_1.csv", encoding = 'latin1')
reviews_2 = pd.read_csv("raw_data/reviews_2.csv", encoding = 'latin1')
reviews_3 = pd.read_csv("raw_data/reviews_3.csv", encoding = 'latin1')
reviews_4 = pd.read_csv("raw_data/reviews_4.csv", encoding = 'latin1')
reviews_5 = pd.read_csv("raw_data/reviews_5.csv", encoding = 'latin1')
reviews_6 = pd.read_csv("raw_data/reviews_6.csv", encoding = 'latin1')

reviews_6.head()
# Out:
#                                 phone_url        date lang country  \
# 0  /cellphones/samsung-instinct-sph-m800/   9/16/2011   en      us
# 1  /cellphones/samsung-instinct-sph-m800/   2/13/2014   en      us
# 2  /cellphones/samsung-instinct-sph-m800/  12/30/2011   en      us
# 3  /cellphones/samsung-instinct-sph-m800/  10/18/2008   en      us
# 4  /cellphones/samsung-instinct-sph-m800/    9/6/2008   en      us
#
#           source             domain  score  score_max  \
# 0    Phone Arena     phonearena.com    8.0       10.0
# 1         Amazon         amazon.com    6.0       10.0
# 2    Phone Scoop     phonescoop.com    9.0       10.0
# 3  HandCellPhone  handcellphone.com    4.0       10.0
# 4   Reviewed.com       reviewed.com    6.0       10.0
#
#                                              extract      author  \
# 0  I've had the phone for awhile and it's a prett...  ajabrams95
# 1  to be clear it is not the sellers fault that t...   Stephanie
# 2  Well i love this phone. i have had ton of phon...    snickers
# 3  I have had my Instinct for several months now ...         A4C
# 4  i have had this instinct phone for about two m...   betaBgood
#
#                      product
# 0        Samsung Instinct HD
# 1  Samsung SPH M800 Instinct
# 2              Instinct M800
# 3           Samsung Instinct
# 4           Samsung Instinct

# %% [markdown]
# Check column names

# %%
reviews_6.columns
# Out:
# Index(['phone_url', 'date', 'lang', 'country', 'source', 'domain', 'score',
#        'score_max', 'extract', 'author', 'product'],
#       dtype='object')

# %% [markdown]
# Concatenate csv files

# %%
reviews = pd.concat([reviews_1, reviews_2, reviews_3, reviews_4, reviews_5, reviews_6], ignore_index=True)
reviews.head()
# Out:
#                         phone_url       date lang country            source  \
# 0  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us  Verizon Wireless
# 1  /cellphones/samsung-galaxy-s8/  4/28/2017   en      us       Phone Arena
# 2  /cellphones/samsung-galaxy-s8/   5/4/2017   en      us            Amazon
# 3  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us           Samsung
# 4  /cellphones/samsung-galaxy-s8/  5/11/2017   en      us  Verizon Wireless
#
#                 domain  score  score_max  \
# 0  verizonwireless.com   10.0       10.0
# 1       phonearena.com   10.0       10.0
# 2           amazon.com    6.0       10.0
# 3          samsung.com    9.2       10.0
# 4  verizonwireless.com    4.0       10.0
#
#                                              extract       author  \
# 0  As a diehard Samsung fan who has had every Sam...   CarolAnn35
# 1  Love the phone. the phone is sleek and smooth ...    james0923
# 2  Adequate feel. Nice heft. Processor's still sl...     R. Craig
# 3  Never disappointed. One of the reasons I've be...  Buster2020
# 4  I've now found that i'm in a group of people t...   S Ate Mine
#
#                                              product
# 0                                  Samsung Galaxy S8
# 1                                  Samsung Galaxy S8
# 2  Samsung Galaxy S8 (64GB) G950U 5.8" 4G LTE Unl...
# 3                      Samsung Galaxy S8 64GB (AT&T)
# 4                                  Samsung Galaxy S8

# %% [markdown]
# ### III. Clean data

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1415133 entries, 0 to 1415132
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415133 non-null  object
#  1   date       1415133 non-null  object
#  2   lang       1415133 non-null  object
#  3   country    1415133 non-null  object
#  4   source     1415133 non-null  object
#  5   domain     1415133 non-null  object
#  6   score      1351644 non-null  float64
#  7   score_max  1351644 non-null  float64
#  8   extract    1395772 non-null  object
#  9   author     1351931 non-null  object
#  10  product    1415132 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 118.8+ MB

# %% [markdown]
# Identify null values

# %%
missing_values = reviews.isna().sum().sort_values(ascending = False)
missing_values
# Out:
# score_max    63489
# score        63489
# author       63202
# extract      19361
# product          1
# domain           0
# source           0
# country          0
# lang             0
# date             0
# phone_url        0
# dtype: int64

# %% [markdown]
# Get the percentage of null values per column

# %%
missing_values.loc[missing_values.gt(0)]/len(reviews)
# Out:
# score_max    4.486433e-02
# score        4.486433e-02
# author       4.466153e-02
# extract      1.368140e-02
# product      7.066474e-07
# dtype: float64

# %% [markdown]
# Since missing values are only 4 percent, the rows are dropped

# %%
reviews.dropna(inplace = True)

# %%
missing_values
# Out:
# score_max    63489
# score        63489
# author       63202
# extract      19361
# product          1
# domain           0
# source           0
# country          0
# lang             0
# date             0
# phone_url        0
# dtype: int64

# %% [markdown]
# Since column 'score_max' contains only the same value, and columns 'domain' and 'extract' are irrelevant for a quantitative analysis, they are also dropped.

# %%
reviews.drop(['score_max', 'domain', 'extract'], axis = 'columns', inplace = True)
reviews.head()
# Out:
#                         phone_url       date lang country            source  \
# 0  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us  Verizon Wireless
# 1  /cellphones/samsung-galaxy-s8/  4/28/2017   en      us       Phone Arena
# 2  /cellphones/samsung-galaxy-s8/   5/4/2017   en      us            Amazon
# 3  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us           Samsung
# 4  /cellphones/samsung-galaxy-s8/  5/11/2017   en      us  Verizon Wireless
#
#    score       author                                            product
# 0   10.0   CarolAnn35                                  Samsung Galaxy S8
# 1   10.0    james0923                                  Samsung Galaxy S8
# 2    6.0     R. Craig  Samsung Galaxy S8 (64GB) G950U 5.8" 4G LTE Unl...
# 3    9.2  Buster2020                       Samsung Galaxy S8 64GB (AT&T)
# 4    4.0   S Ate Mine                                  Samsung Galaxy S8

# %% [markdown]
# Since the entries in column 'product' appear in varying forms, they are replaced by an extraction from the url.

# %%
reviews['product'] = (reviews['phone_url'].str.split('/')
                                          .str.get(2))
reviews.head()
# Out:
#                         phone_url       date lang country            source  \
# 0  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us  Verizon Wireless
# 1  /cellphones/samsung-galaxy-s8/  4/28/2017   en      us       Phone Arena
# 2  /cellphones/samsung-galaxy-s8/   5/4/2017   en      us            Amazon
# 3  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us           Samsung
# 4  /cellphones/samsung-galaxy-s8/  5/11/2017   en      us  Verizon Wireless
#
#    score       author            product
# 0   10.0   CarolAnn35  samsung-galaxy-s8
# 1   10.0    james0923  samsung-galaxy-s8
# 2    6.0     R. Craig  samsung-galaxy-s8
# 3    9.2  Buster2020   samsung-galaxy-s8
# 4    4.0   S Ate Mine  samsung-galaxy-s8

# %%
reviews['product'].value_counts()
# Out:
# samsung-galaxy-s6         15869
# samsung-galaxy-s7-edge    15568
# apple-iphone-5s           15543
# samsung-galaxy-s5         15282
# motorola-moto-g           14431
#                           ...
# sanyo-s750                    1
# philips-xenium-9-9s           1
# blu-life-one                  1
# tiptel-ergophone-6010         1
# toshiba-k01                   1
# Name: product, Length: 5508, dtype: int64

# %% [markdown]
# Check product grouped for initial analysis

# %%
product_grouped = reviews.groupby('product')
product_grouped.first().reset_index()
# Out:
#                     product                           phone_url        date  \
# 0     acer-acer-liquid-m220  /cellphones/acer-acer-liquid-m220/   29/6/2015
# 1              acer-allegro           /cellphones/acer-allegro/    9/8/2012
# 2         acer-betouch-e100      /cellphones/acer-betouch-e100/  12/26/2014
# 3         acer-betouch-e101      /cellphones/acer-betouch-e101/    1/2/2010
# 4         acer-betouch-e110      /cellphones/acer-betouch-e110/   4/24/2011
# ...                     ...                                 ...         ...
# 5503               zte-zmax               /cellphones/zte-zmax/   5/10/2016
# 5504             zte-zmax-2             /cellphones/zte-zmax-2/  11/22/2016
# 5505         zte-zte-g-r221         /cellphones/zte-zte-g-r221/    1/8/2017
# 5506         zte-zte-g-s213         /cellphones/zte-zte-g-s213/   1/19/2013
# 5507         zte-zte-u-f930         /cellphones/zte-zte-u-f930/  10/23/2012
#
#      lang country       source  score                         author
# 0      en      us       Amazon    2.0                    karitoki411
# 1      it      it         Ciao    8.0                        babetti
# 2      en      gb       Amazon    2.0                marilyn mertens
# 3      en      gb       Amazon    2.0                    A.Humphreys
# 4      en      gb       Amazon    6.0  C. L. Weekes "Charliegadgets"
# ...   ...     ...          ...    ...                            ...
# 5503   en      us         CNET   10.0                   youngkim3000
# 5504   en      us       Newegg    8.0                       Chuck C.
# 5505   ru      ru   Irecommend   10.0                        LALYA30
# 5506   en      us  Phone Arena    7.0                         Crisma
# 5507   it      it         Ciao    6.0                       keting11
#
# [5508 rows x 8 columns]

# %% [markdown]
# For deeper analysis column 'brand' is added.

# %%
reviews['brand'] = (reviews['product'].str.split("-")
                                      .str.get(0))
                                      
reviews.head()
# Out:
#                         phone_url       date lang country            source  \
# 0  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us  Verizon Wireless
# 1  /cellphones/samsung-galaxy-s8/  4/28/2017   en      us       Phone Arena
# 2  /cellphones/samsung-galaxy-s8/   5/4/2017   en      us            Amazon
# 3  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us           Samsung
# 4  /cellphones/samsung-galaxy-s8/  5/11/2017   en      us  Verizon Wireless
#
#    score       author            product    brand
# 0   10.0   CarolAnn35  samsung-galaxy-s8  samsung
# 1   10.0    james0923  samsung-galaxy-s8  samsung
# 2    6.0     R. Craig  samsung-galaxy-s8  samsung
# 3    9.2  Buster2020   samsung-galaxy-s8  samsung
# 4    4.0   S Ate Mine  samsung-galaxy-s8  samsung

# %% [markdown]
# Check brand grouped for initial analysis

# %%
brand_grouped = reviews.groupby('brand')
brand_grouped.first().reset_index()
# Out:
#         brand                               phone_url        date lang  \
# 0        acer           /cellphones/acer-liquid-z630/   8/19/2016   en
# 1     alcatel  /cellphones/alcatel-one-touch-idol-4s/   9/26/2016   en
# 2      amazon          /cellphones/amazon-fire-phone/   2/28/2016   en
# 3        amoi                  /cellphones/amoi-a203/    7/1/2012   fr
# 4    amplicom             /cellphones/amplicom-m5010/   1/11/2016   de
# ..        ...                                     ...         ...  ...
# 160      yezz             /cellphones/yezz-billy-4-7/  10/20/2014   en
# 161      yota           /cellphones/yota-yotaphone-2/  12/12/2014   en
# 162        yu                /cellphones/yu-yuphoria/   5/17/2017   en
# 163      zopo         /cellphones/zopo-color-c-zp330/  11/21/2015   en
# 164       zte                 /cellphones/zte-axon-7/  12/22/2016   en
#
#     country      source  score              author                    product
# 0        gb        Ciao    6.0       cynthia-melky           acer-liquid-z630
# 1        us        CNET   10.0           JoeRanger  alcatel-one-touch-idol-4s
# 2        us        CNET    6.0  KungalooshMeganium          amazon-fire-phone
# 3        fr  LesMobiles    9.6             peter13                  amoi-a203
# 4        de      Amazon   10.0     Gottfried Fiala             amplicom-m5010
# ..      ...         ...    ...                 ...                        ...
# 160      us      Amazon   10.0        Louis A Cruz             yezz-billy-4-7
# 161      us        CNET    9.0   Vladimir.V.Kozlov           yota-yotaphone-2
# 162      in   Smartprix    9.0   barath uppalancha                yu-yuphoria
# 163      gb      Amazon    2.0          Simon King         zopo-color-c-zp330
# 164      us        CNET   10.0     mountain_man_ky                 zte-axon-7
#
# [165 rows x 9 columns]

# %% [markdown]
# Since it is irrelevant for further analysis, drop column "phone_url"

# %%
reviews.drop(['phone_url'], axis = 'columns', inplace = True)

# %%
reviews.head()
# Out:
#         date lang country            source  score       author  \
# 0   5/2/2017   en      us  Verizon Wireless   10.0   CarolAnn35
# 1  4/28/2017   en      us       Phone Arena   10.0    james0923
# 2   5/4/2017   en      us            Amazon    6.0     R. Craig
# 3   5/2/2017   en      us           Samsung    9.2  Buster2020
# 4  5/11/2017   en      us  Verizon Wireless    4.0   S Ate Mine
#
#              product    brand
# 0  samsung-galaxy-s8  samsung
# 1  samsung-galaxy-s8  samsung
# 2  samsung-galaxy-s8  samsung
# 3  samsung-galaxy-s8  samsung
# 4  samsung-galaxy-s8  samsung

# %%
reviews.shape
# Out:
# (1275917, 8)

# %%
reviews['country'].nunique()
# Out:
# 40

# %%
reviews['date'].str.split('/').str.get(2).max()
# Out:
# '2017'

# %%
reviews['date'].str.split('/').str.get(2).min()
# Out:
# '1970'

# %% [markdown]
# ## IV. Export dataframe to csv file

# %%
reviews.to_csv("cell_phones.csv")
